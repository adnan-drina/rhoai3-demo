# %% [markdown]
# # Enterprise RAG with AG News\n\nThis notebook runs the Stage 230 acceptance flow against the GitOps-managed Llama Stack, Milvus, Qwen3 reranker, and MaaS-backed Nemotron model.

# %%
# %cd /opt/app-root/src/rhoai3-demo/stage-230-private-data-rag\n!python scripts/agnews_rag_acceptance.py --reset
